# %%
from agent_scripts.buck import Buck
import asyncio
import nest_asyncio
import pandas as pd
from datetime import datetime

# Enable nested event loops
nest_asyncio.apply()

async def main():
    buck_get_data = Buck()._create_default_data_provider()
    data = await buck_get_data.get_news_data("BHEL.NS")
    
    # Convert news data to DataFrame
    news_df = pd.DataFrame(data['news'])
    
    # Convert pub_date strings to datetime
    news_df['pub_date'] = pd.to_datetime(news_df['pub_date'])
    
    # Sort by publication date
    news_df = news_df.sort_values('pub_date', ascending=False)
    
    print("News data shape:", news_df.shape)
    print("\nFirst few rows:")
    print(news_df[['title', 'source', 'pub_date']].head())
    return news_df
# Run the async function
news_df = asyncio.run(main())
# Out:
# [2025-06-20 04:43:00] INFO | Stock Agent initialized successfully
# News data shape: (20, 7)
#
# First few rows:
#                                                title  ...            pub_date
# 0  TCS says none of its systems were compromised ...  ... 2025-06-19 20:27:20
# 1  TCS says co not under probe in M&S breach; Cha...  ... 2025-06-19 20:26:28
# 2  Zee promoters to recover Rs 1,300 crore, raise...  ... 2025-06-19 20:16:00
# 3    M&S investigates cyber breach; TCS out of probe  ... 2025-06-19 20:15:00
# 4  Shubhranshu Singh and Sumit Virmani in Global ...  ... 2025-06-19 20:08:51
#
# [5 rows x 3 columns]

# %%
news_df
# Out:
#                                                 title  ...                                            topics
# 0   TCS says none of its systems were compromised ...  ...                            [Regulatory and Legal]
# 1   TCS says co not under probe in M&S breach; Cha...  ...                            [Regulatory and Legal]
# 2   Zee promoters to recover Rs 1,300 crore, raise...  ...                                                []
# 3     M&S investigates cyber breach; TCS out of probe  ...                            [Regulatory and Legal]
# 4   Shubhranshu Singh and Sumit Virmani in Global ...  ...                         [Awards and Recognitions]
# 5   U.S. team mobilised to control gas leak in ONG...  ...                          [Operational Challenges]
# 6                  Broker’s call: Chalet Hotels (Buy)  ...                                                []
# 7   IT union AIITEU slams TCS' 225-day billability...  ...                            [Regulatory and Legal]
# 8         City Union Bank gets Digital Payments Award  ...                         [Awards and Recognitions]
# 9   ONGC Gas Leak in Assam: Specialists on the job...  ...                                                []
# 10  Yes Bank CEO gets six-month extension as SMBC ...  ...                            [Regulatory and Legal]
# 11  Cyient CSR arm, ICT Academy to offer programme...  ...                                   [New Offerings]
# 12  Indias first-ever hydrogen-powered buses to be...  ...                                   [New Offerings]
# 13  Meet The Five Indian Startups Selected For Mar...  ...  [Procurement and Sales, Artificial Intelligence]
# 14  New Vida VX2 To Miss Out On Disc Brakes- Tease...  ...                                   [New Offerings]
# 15  HDB Financial to launch Rs 12,500 crore IPO on...  ...                              [Funding Activities]
# 16  Uno Minda to invest ₹210 crore on a new alumin...  ...                              [Capital Investment]
# 17  Why health insurance costs are rising and how ...  ...                                                []
# 18  Why health insurance costs are rising and how ...  ...                                                []
# 19  Sun TV Family Feud: DMK MP Dayanidhi Maran sen...  ...                            [Regulatory and Legal]
#
# [20 rows x 7 columns]

# %%
news_df = pd.read_csv('/Users/code.ai/Stocks/Buck_V1/buck_visualizer/data-viz/BHEL.NS_news_20250620_051339.csv')
news_df
# Out:
#                                                 title  ...                                       full_content
# 0   Mysuru’s waste to power clean energy, fuel MCC...  ...  Mysuru’s waste to power clean energy, fuel MCC...
# 1   TCS says none of its systems were compromised ...  ...                                                NaN
# 2   TCS says co not under probe in M&S breach; Cha...  ...                                                NaN
# 3   Zee promoters to recover Rs 1,300 crore, raise...  ...                                                NaN
# 4     M&S investigates cyber breach; TCS out of probe  ...  'M&S investigates cyber breach; TCS out of pro...
# 5   Shubhranshu Singh and Sumit Virmani in Global ...  ...  World's Most Influential CMOs: Shubhranshu Sin...
# 6   U.S. team mobilised to control gas leak in ONG...  ...  U.S. team mobilised to control gas leak in ONG...
# 7                  Broker’s call: Chalet Hotels (Buy)  ...  Broker’s call: Chalet Hotels (Buy) - The Hindu...
# 8   IT union AIITEU slams TCS' 225-day billability...  ...                                                NaN
# 9         City Union Bank gets Digital Payments Award  ...  City Union Bank gets Digital Payments Award - ...
# 10  ONGC Gas Leak in Assam: Specialists on the job...  ...  ONGC Gas Leak in Assam: Specialists on the job...
# 11  Yes Bank CEO gets six-month extension as SMBC ...  ...                                                NaN
# 12  Cyient CSR arm, ICT Academy to offer programme...  ...  Cyient CSR arm, ICT Academy to offer programme...
# 13  Indias first-ever hydrogen-powered buses to be...  ...  India's first-ever hydrogen-powered buses to b...
# 14  Meet The Five Indian Startups Selected For Mar...  ...  Meet The Five Indian Startups Selected For Mar...
# 15  New Vida VX2 To Miss Out On Disc Brakes- Tease...  ...                                                NaN
# 16  HDB Financial to launch Rs 12,500 crore IPO on...  ...  HDB Financial to launch Rs 12,500 crore IPO on...
# 17  Uno Minda to invest ₹210 crore on a new alumin...  ...  Uno Minda to invest ₹210 crore on a new alumin...
# 18  Why health insurance costs are rising and how ...  ...  Why health insurance costs are rising and how ...
# 19  Why health insurance costs are rising and how ...  ...  Why health insurance costs are rising and how ...
#
# [20 rows x 8 columns]
